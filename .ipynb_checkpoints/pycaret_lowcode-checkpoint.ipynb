# %%
#!pip install pycaret

# %% [markdown]
# ### Import Required Packages and load data

# %%
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.shape
# Out:
# (1338, 7)

# %%
data_seen = data.sample(frac=0.9, random_state=786).reset_index(drop=True)
data_unseen = data.drop(data_seen.index).reset_index(drop=True)

print('Data for Modeling: ' + str(data_seen.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (1204, 7)
# Unseen Data For Predictions: (134, 7)

# %% [markdown]
# ### Model Buliding

# %%
from pycaret.regression import *

# %% [markdown]
# ### a) Setting up Environment in Pycaret

# %%
exp_101 = setup(data_seen, target = 'charges', session_id = 123,normalize = True,polynomial_features = True, trigonometry_features = True, feature_interaction=True, 
           bin_numeric_features= ['age', 'bmi'])
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row15_col1 {
#             background-color:  lightgreen;
#         }    #T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row25_col1 {
#             background-color:  lightgreen;
#         }    #T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row32_col1 {
#             background-color:  lightgreen;
#         }    #T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row34_col1 {
#             background-color:  lightgreen;
#         }    #T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row39_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row3_col1" class="data row3 col1" >(1204, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row5_col1" class="data row5 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row6_col1" class="data row6 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row10_col1" class="data row10 col1" >(1204, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row11_col1" class="data row11 col1" >(842, 60)</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row12_col1" class="data row12 col1" >(362, 60)</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_f973fa54_aa6b_11ea_891c_b8ca3adc8944row17_col0" class="data row17 col0" >Transformation </td>

# %%
exp_101[0].columns
# Out:
# Index(['age_Power2', 'bmi_Power2', 'sex_female', 'children_0', 'children_1',
#        'children_2', 'children_3', 'children_4', 'children_5', 'smoker_no',
#        'region_northeast', 'region_northwest', 'region_southeast',
#        'region_southwest', 'age_0.0', 'age_1.0', 'age_10.0', 'age_11.0',
#        'age_2.0', 'age_3.0', 'age_4.0', 'age_5.0', 'age_6.0', 'age_7.0',
#        'age_8.0', 'age_9.0', 'bmi_0.0', 'bmi_1.0', 'bmi_10.0', 'bmi_11.0',
#        'bmi_2.0', 'bmi_3.0', 'bmi_4.0', 'bmi_5.0', 'bmi_6.0', 'bmi_7.0',
#        'bmi_8.0', 'bmi_9.0', 'smoker_no_multiply_bmi_Power2',
#        'children_0_multiply_bmi_Power2',
#        'bmi_Power2_multiply_region_southeast',
#        'bmi_Power2_multiply_age_Power2', 'age_9.0_multiply_bmi_Power2',
#        'children_0_multiply_age_Power2', 'sex_female_multiply_bmi_Power2',
#        'region_southeast_multiply_bmi_Power2', 'smoker_no_multiply_children_0',
#        'age_Power2_multiply_bmi_Power2', 'bmi_Power2_multiply_age_7.0',
#        'age_Power2_multiply_children_0', 'age_0.0_multiply_smoker_no',
#        'age_Power2_multiply_smoker_no', 'smoker_no_multiply_sex_female',
#        'sex_female_multiply_age_Power2', 'children_2_multiply_bmi_Power2',
#        'smoker_no_multiply_age_Power2', 'region_southeast_multiply_smoker_no',
#        'bmi_Power2_multiply_smoker_no', 'children_1_multiply_bmi_Power2',
#        'region_northeast_multiply_bmi_Power2'],
#       dtype='object')

# %% [markdown]
# #### Creating List of models

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944 th {
#           text-align: left;
#     }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row0_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row0_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row1_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row1_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row2_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row2_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row3_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row3_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row4_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row4_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row5_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row5_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row6_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row6_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row7_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row7_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row8_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row8_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row9_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row9_col4 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row10_col0 {
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2996731c_aa6d_11ea_a22e_b8ca3adc8944row10_col3 {
#             : ;

# %% [markdown]
# ### Choose the top model

# %%
egb = create_model('xgboost')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     2600.7476  1.863469e+07  4316.7920  0.8813  0.4378  0.3264
# 1     1823.7825  7.676067e+06  2770.5717  0.9594  0.3072  0.2593
# 2     2474.1612  1.566832e+07  3958.3223  0.8787  0.4083  0.3278
# 3     3004.7836  2.922324e+07  5405.8520  0.7481  0.5352  0.3309
# 4     2915.7857  2.968932e+07  5448.7910  0.8121  0.4496  0.2422
# 5     2563.9432  1.981406e+07  4451.2992  0.8622  0.4381  0.3229
# 6     2757.9862  2.291073e+07  4786.5157  0.8741  0.4494  0.3484
# 7     2598.6851  2.268354e+07  4762.7243  0.7879  0.4478  0.3148
# 8     2207.1466  1.284063e+07  3583.3824  0.9366  0.4184  0.3646
# 9     2479.0279  2.934776e+07  5417.3569  0.7420  0.4715  0.2393
# Mean  2542.6050  2.084884e+07  4490.1607  0.8482  0.4363  0.3077
# SD     323.1420  7.061148e+06   829.0311  0.0702  0.0541  0.0422

# %% [markdown]
# ### Tuning Model

# %%
tune_egb = tune_model('xgboost')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     3080.8560  2.371126e+07  4869.4210  0.8489  0.6205  0.3595
# 1     2352.7338  1.203653e+07  3469.3710  0.9363  0.4247  0.3862
# 2     2883.9189  2.306196e+07  4802.2866  0.8214  0.4859  0.4032
# 3     3230.0154  3.335565e+07  5775.4349  0.7125  0.6975  0.3703
# 4     3182.3808  3.438483e+07  5863.8579  0.7824  0.5503  0.2805
# 5     2991.0186  2.393396e+07  4892.2345  0.8335  0.5751  0.4068
# 6     3059.4368  2.634253e+07  5132.4972  0.8552  0.4760  0.3920
# 7     2932.9240  2.577718e+07  5077.1229  0.7589  0.5481  0.3876
# 8     2518.4195  1.559141e+07  3948.5954  0.9230  0.4941  0.4585
# 9     2916.1242  3.441172e+07  5866.1502  0.6975  0.5405  0.2845
# Mean  2914.7828  2.526070e+07  4969.6971  0.8170  0.5413  0.3729
# SD     264.4965  7.150702e+06   750.2079  0.0762  0.0742  0.0517

# %%
print(tune_egb)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.5, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=110, min_child_weight=1, missing=None, n_estimators=800,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=123,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=0.5, verbosity=0)

# %% [markdown]
# ### Plot a model

# %%
plot_model(tune_egb)

# %%
plot_model(tune_egb, plot = 'error')

# %% [markdown]
# ### Feature Importance Plot

# %%
plot_model(tune_egb, plot='feature')

# %% [markdown]
# ### Predict on Test/Hold-out sample

# %%
save_model(lr, 'deployment_28042020')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
deployment_28042020 = load_model('deployment_28042020')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
deployment_28042020
# Out:
# [Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        ml_usecase='regression',
#                                        numerical_features=[], target='charges',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  numeric_strategy='mean',
#                                  target_variable=None)),
#                  ('new_levels1',
#                   New_Catagorical_Levels...
#                  ('dummy', Dummify(target='charges')),
#                  ('fix_perfect', Remove_100(target='charges')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', Empty()), ('fix_multi', Empty()),
#                  ('dfs',
#                   DFS_Classic(interactions=['multiply'], ml_usecase='regression',
#                               random_state=123, subclass='binary',
#                               target='charges',
#                               top_features_to_pick_percentage=None)),
#                  ('pca', Empty())],
#           verbose=False),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  None]

# %%
import requests
url = 'https://pycaret-insurance.herokuapp.com/predict_api'
pred = requests.post(url,json={'age':55, 'sex':'male', 'bmi':59, 'children':1, 'smoker':'male', 'region':'northwest'})
print(pred.json())
# Out:
# 75714.0
